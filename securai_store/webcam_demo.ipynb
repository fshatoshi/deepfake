# %% [markdown]
# # Webcam Colab — démo SecurAI (sans SSH)
#
# Copie `securai_store` sur Drive : `MyDrive/Vision_project/securai_store`

# %%
from google.colab import drive
drive.mount('/content/drive')
SECURAI_BASE = '/content/drive/MyDrive/Vision_project/securai_store'
import os
os.environ['SECURAI_BASE'] = SECURAI_BASE

# %%
# !pip install -q opencv-python pillow tqdm facenet-pytorch
# !pip install -q torch torchvision --index-url https://download.pytorch.org/whl/cu121

# %%
import sys
sys.path.insert(0, SECURAI_BASE)
from modules.face_recognizer import FaceRecognizer
from modules.patch_attacker import PatchAttacker
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'[INFO] Device: {device}')
face_rec = FaceRecognizer()
patch_attacker = PatchAttacker(face_rec.model)
